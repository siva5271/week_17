# %%
import cv2

# %%
image=cv2.imread(\
   '/home/siva/Downloads/opencv-4.x/samples/data/aero1.jpg',1)
image
# Out:
# array([[[173, 153, 128],
#         [173, 153, 128],
#         [174, 154, 129],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[171, 150, 128],
#         [171, 151, 126],
#         [172, 151, 129],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[169, 148, 127],
#         [170, 149, 127],
#         [171, 150, 129],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[104, 121, 110],
#         [102, 119, 108],
#         [103, 119, 108],
#         ...,
#         [112, 115, 129],
#         [112, 113, 127],
#         [114, 115, 129]],
#
#        [[105, 122, 111],
#         [103, 120, 109],
#         [103, 119, 108],
#         ...,
#         [106, 107, 121],
#         [108, 109, 123],
#         [114, 115, 129]],
#
#        [[101, 118, 107],
#         [ 99, 116, 105],
#         [ 99, 115, 104],
# ...

# %%
cv2.imshow('image',image)
# Out:
# ...
# QObject::moveToThread: Current thread (0x1643de0) is not the object's thread (0xe64640).
# Cannot move to target thread (0x1643de0)
#
# QObject::moveToThread: Current thread (0x1643de0) is not the object's thread (0xe64640).
# Cannot move to target thread (0x1643de0)
#
# QObject::moveToThread: Current thread (0x1643de0) is not the object's thread (0xe64640).
# Cannot move to target thread (0x1643de0)
#
# QObject::moveToThread: Current thread (0x1643de0) is not the object's thread (0xe64640).
# Cannot move to target thread (0x1643de0)
#
# QObject::moveToThread: Current thread (0x1643de0) is not the object's thread (0xe64640).
# Cannot move to target thread (0x1643de0)
#
# QObject::moveToThread: Current thread (0x1643de0) is not the object's thread (0xe64640).
# Cannot move to target thread (0x1643de0)
#
# QObject::moveToThread: Current thread (0x1643de0) is not the object's thread (0xe64640).
# Cannot move to target thread (0x1643de0)
#
# ...
